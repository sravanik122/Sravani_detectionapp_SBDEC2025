# %%
import plotly.express as px

data = {
    "Year": [2018, 2019, 2020, 2021, 2022],
    "Sales": [100, 150, 130, 170, 180]
}

fig = px.line(data, x="Year", y="Sales", title="Sales Growth Over Years")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import plotly.express as px
#       3 data = {
#       4     "Year": [2018, 2019, 2020, 2021, 2022],
#       5     "Sales": [100, 150, 130, 170, 180]
#       6 }
#       8 fig = px.line(data, x="Year", y="Sales", title="Sales Growth Over Years")
#
# File ~\anaconda3\Lib\site-packages\plotly\express\__init__.py:27
#      11 if np is None:
#      12     raise ImportError(
#      13         """\
#      14 Plotly Express requires numpy to be installed. You can install numpy using pip with:
#    (...)
#      24 """
#      25     )
# ---> 27 from ._imshow import imshow
#      28 from ._chart_types import (  # noqa: F401
#      29     scatter,
#      30     scatter_3d,
#    (...)
#      67     density_mapbox,
#      68 )
#      71 from ._core import (  # noqa: F401
#      72     set_mapbox_access_token,
#      73     defaults,
#      74     get_trendline_results,
#      75     NO_COLOR,
#      76 )
#
# File ~\anaconda3\Lib\site-packages\plotly\express\_imshow.py:11
#       8 from plotly.utils import image_array_to_data_uri
#      10 try:
# ---> 11     import xarray
#      13     xarray_imported = True
#      14 except ImportError:
#
# File ~\anaconda3\Lib\site-packages\xarray\__init__.py:3
#       1 from xarray import testing, tutorial
#       2 from xarray.backends.api import (
# ----> 3     load_dataarray,
#       4     load_dataset,
#       5     open_dataarray,
#       6     open_dataset,
#       7     open_mfdataset,
#       8     save_mfdataset,
#       9 )
#      10 from xarray.backends.zarr import open_zarr
#      11 from xarray.coding.cftime_offsets import cftime_range, date_range, date_range_like
#
# File ~\anaconda3\Lib\site-packages\xarray\coders.py:6
#       1 """
#       2 This module provides coder objects that encapsulate the
#       3 "encoding/decoding" process.
#       4 """
# ----> 6 from xarray.coding.times import CFDatetimeCoder, CFTimedeltaCoder
#       8 __all__ = ["CFDatetimeCoder", "CFTimedeltaCoder"]
#
# File ~\anaconda3\Lib\site-packages\xarray\coding\times.py:15
#      12 import pandas as pd
#      13 from pandas.errors import OutOfBoundsDatetime, OutOfBoundsTimedelta
# ---> 15 from xarray.coding.common import (
#      16     SerializationWarning,
#      17     VariableCoder,
#      18     lazy_elemwise_func,
#      19     pop_to,
#      20     safe_setitem,
#      21     unpack_for_decoding,
#      22     unpack_for_encoding,
#      23 )
#      24 from xarray.compat.pdcompat import default_precision_timestamp, timestamp_as_unit
#      25 from xarray.core import indexing
#
# File ~\anaconda3\Lib\site-packages\xarray\coding\common.py:8
#       4 from typing import TYPE_CHECKING, Any, Union
#       6 import numpy as np
# ----> 8 from xarray.core import indexing
#       9 from xarray.core.variable import Variable
#      10 from xarray.namedarray.parallelcompat import get_chunked_array_type
#
# File ~\anaconda3\Lib\site-packages\xarray\core\indexing.py:19
#      16 from numpy.typing import DTypeLike
#      17 from packaging.version import Version
# ---> 19 from xarray.core import duck_array_ops
#      20 from xarray.core.coordinate_transform import CoordinateTransform
#      21 from xarray.core.nputils import NumpyVIndexAdapter
#
# File ~\anaconda3\Lib\site-packages\xarray\core\duck_array_ops.py:27
#      17 from numpy import all as array_all  # noqa
#      18 from numpy import any as array_any  # noqa
#      19 from numpy import (  # noqa
#      20     around,  # noqa
#      21     einsum,
#      22     gradient,
#      23     isclose,
#      24     isin,
#      25     isnat,
#      26     take,
# ---> 27     tensordot,
#      28     transpose,
#      29     unravel_index,
#      30     zeros_like,  # noqa
#      31 )
#      32 from numpy import concatenate as _concatenate
#      33 from numpy.core.multiarray import normalize_axis_index  # type: ignore[attr-defined]
#
# File ~\anaconda3\Lib\site-packages\xarray\compat\dask_array_ops.py:6
#       3 import math
#       5 from xarray.compat.dask_array_compat import reshape_blockwise
# ----> 6 from xarray.core import dtypes, nputils
#       9 def dask_rolling_wrapper(moving_func, a, window, min_count=None, axis=-1):
#      10     """Wrapper to apply bottleneck moving window funcs on dask arrays"""
#
# File ~\anaconda3\Lib\site-packages\xarray\core\nputils.py:15
#      12 from xarray.namedarray import pycompat
#      14 # remove once numpy 2.0 is the oldest supported version
# ---> 15 if module_available("numpy", minversion="2.0.0.dev0"):
#      16     from numpy.lib.array_utils import (  # type: ignore[import-not-found,unused-ignore]
#      17         normalize_axis_index,
#      18     )
#      19 else:
#
# TypeError: module_available() got an unexpected keyword argument 'minversion'
